# %%
# Import statements

import numpy as np
import matplotlib.pyplot as plt

import matplotlib
from skimage import color
from scipy.ndimage import imread
from skimage.transform import resize
from pylab import rcParams

#ipython setting
rcParams['figure.figsize'] = (20, 12)

# %% [markdown]
# $\newcommand{\vecl}[1]{\begin{pmatrix}#1\end{pmatrix}}$
# $\newcommand{\hvec}[1]{\widetilde{\boldsymbol{#1}}}$
# $\newcommand{\nvec}[1]{\boldsymbol{#1}}$

# %% [markdown]
# ## Histogram of oriented gradients

# %% [markdown]
# --Text--

# %%
def subImage(f, yRange, xRange, yAnchor, xAnchor):
    
    return f[xAnchor:xAnchor+xRange:, yAnchor:yAnchor+yRange:]

bolt = resize(color.rgb2gray(subImage(imread('bolt2.png'), 100, 200, 205, 95)), (128, 64))

plt.imshow(bolt, cmap='gray')
plt.show()

# %%
def cart2polar(fx, fy):
    
    mag = np.sqrt(fx * fx + fy * fy)
    angle = np.arctan2(fy, fx)
    
    return mag, angle
    
def HOG8x8(fx, fy):
    
    mags, angles =  cart2polar(fx, fy)
    shapeX, shapeY = fx.shape
    mags = mags.reshape(shapeX * shapeY)
    angles = angles.reshape(shapeX * shapeY)
    # keep angles between 0 and pi
    angles[angles < 0] += np.pi
    
    return np.histogram(angles, bins=np.linspace(0, np.pi, 10), weights=mags)
    

gx = np.ones((8,8))*np.sin(np.pi/4)
gy = np.ones((8,8))*np.cos(np.pi/4)
hist, bin_edges = HOG8x8(gx, gy)

binWidth = (bin_edges[0] + bin_edges[1])

plt.bar(bin_edges[:-1] + binWidth / 2, hist + np.array([1,1,1,1,1,1,1,1,1]), width=binWidth)
plt.xlim(min(bin_edges), max(bin_edges))
plt.show()

# %% [markdown]
# 1
#
# 1
#
# 1
#
# 1
#
# 1
#
# 1
#
# 1

# %%
from numpy.linalg import norm

def HOGblock(h1, h2, h3, h4):
    
    # Combine vectors into one single vector
    blockVector = np.hstack((h1, h2, h3, h4))
    # Normalise and return
    return (blockVector / norm(blockVector))

t = [np.array([1, 2, 3, 4, 5, 6]) for _ in range(5)]
print("Shape of input vector: %s, length: %s" % (t[0].shape, norm(t[0])))
block = HOGblock(t[0], t[2], t[3], t[4])
print("Shape of output vector: %s, length: %s" % (block.shape, norm(block)))
# Out:
# Shape of input vector: (6,), length: 9.53939201417
# Shape of output vector: (24,), length: 1.0

# %%
from skimage.filters import sobel_h, sobel_v

def rose(HOG, pos, ax):
    
    angles = np.linspace(0, np.pi, 10)
    
    for angle, length in zip(HOG, angles):
        ax.plot([pos[0] - length * np.sin(angle), pos[0] + length * np.sin(angle)],
                [pos[1] - length * np.cos(angle), pos[1] + length * np.cos(angle)], color="red")

def HOGimage(f):
    
    # Convert image to grayscale for use in sobel filter
    f = color.rgb2gray(f)
    
    # Calculate gradients of image
    fx = sobel_h(f)
    fy = sobel_v(f)
    
    # Pick out subimage and resize
    bolt_fx = resize(subImage(fx, 100, 200, 205, 95), (128, 64))
    bolt_fy = resize(subImage(fy, 100, 200, 205, 95), (128, 64))
    
    # Set up iterator
    xs = [n for _ in range(16) for n in range(0, 57, 8)]
    ys = [n for n in range(0, 121, 8) for _ in range(8)]
    
    # Divide gradient image into blocks
    blocks_fx = [bolt_fx[x:x+8:,y:y+8:] for y, x in zip(xs, ys)]
    blocks_fy = [bolt_fy[x:x+8:,y:y+8:] for y, x in zip(xs, ys)]

    # Calculate HOG for each 8x8 cell
    HOGs = [HOG8x8(xs, ys)[0] for xs, ys in zip(blocks_fx, blocks_fy)]
    HOGsNorm = [HOG / norm(HOG) for HOG in HOGs]
    
    # Normalise HOGs over 16x16 blocks
    HOGblocks = [HOGblock(HOGs[x + y], HOGs[x + y + 1], HOGs[x + y + 8], HOGs[x + y + 9]) for x in range(7) for y in range(15)]

    positions = [(x, y) for x in np.linspace(4, 60, 8) for y in np.linspace(4, 124, 16)]

    fig, ax = plt.subplots(1, 1)
    ax.imshow(resize(subImage(f, 100, 200, 205, 95), (128, 64)), cmap='gray')
    
    #Plot rose of directions for each HOG (NOT using the full HOG desciptor)
    for HOG, pos in zip(HOGsNorm, positions):
        rose(HOG, pos, ax)

    plt.show()
    
HOGimage(imread('bolt2.png'))
